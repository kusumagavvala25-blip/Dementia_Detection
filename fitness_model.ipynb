# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import joblib

# Load dataset
data = pd.read_csv("fitness.csv")

# Print column names to check dataset
print("Columns in dataset:", data.columns)

# Select features
X = data[["Age","Height","Weight","Duration","Heart_Rate"]]

# Target
y = data["Calories"]

# Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Train model
model = LinearRegression()
model.fit(X_train, y_train)

# Save model
joblib.dump(model,"fitness_model.pkl")

print("Model created successfully")
# Out:
# Columns in dataset: Index(['title', 'description', 'level', 'goal', 'equipment', 'program_length',
#        'time_per_workout', 'week', 'day', 'number_of_exercises',
#        'exercise_name', 'sets', 'reps', 'intensity', 'created', 'last_edit'],
#       dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 13
#      10 print("Columns in dataset:", data.columns)
#      12 # Select features
# ---> 13 X = data[["Age","Height","Weight","Duration","Heart_Rate"]]
#      15 # Target
#      16 y = data["Calories"]
#
# File c:\Users\pvspr\anaconda3\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\pvspr\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File c:\Users\pvspr\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6261, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6259 if nmissing:
#    6260     if nmissing == len(indexer):
# -> 6261         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6264     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Age', 'Height', 'Weight', 'Duration', 'Heart_Rate'], dtype='object')] are in the [columns]"
